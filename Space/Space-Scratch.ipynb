# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def rocket(fuel_ratio):
    v_e = 4400
    log_ = np.log(fuel_ratio)
    return log_

# %%
fuel_ratio = np.linspace(0,200, num=200)


fig, ax = plt.subplots(figsize=(15,8))

ax.plot(fuel_ratio, rocket(fuel_ratio))
ax.axhline(y=0, ls='--', c='red')
# ax.axhline(y=18000, ls='--', c='green')
